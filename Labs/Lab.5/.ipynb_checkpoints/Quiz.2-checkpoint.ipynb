# %% [markdown]
# Quiz 2:
#
# Write a function make_deck that returns a list of all of the cards in a standard card deck. The return should be a list of tuples of pairs of suit and value. For example the 10 of Clubs would be ('Clubs', 10) and Queen of Hearts would be ('Hearts', 'Queen'). Recall that a deck has 52 cards, divided into 4 suits (Clubs, Diamonds, Hearts, and Spades), and that each suit has 13 cards: 2 to 10, Jack, Queen, King, and Ace. Summit your solution with Lab 5.

# %%
# Function creating a standard deck of cards

def make_deck():
    """Returns a list of tuples representing a standard deck of 52 cards."""
    suits = ['Clubs', 'Diamonds', 'Hearts', 'Spades']
    values = [2, 3, 4, 5, 6, 7, 8, 9, 10, 'Jack', 'Queen', 'King', 'Ace']
    
    # Generating a list of (suit, value) pairs
    deck = [(suit, value) for suit in suits for value in values]
    
    return deck


# testing
deck = make_deck()


# Displaying first 5 cards to check
print("First 5 cards in the deck:")
for card in deck[:5]:
    print(card)


# Checking the total number of cards in the deck
print("\nTotal cards in deck:", len(deck))


# Checking if the Ace of Spades is in the deck
print("\nIs ('Spades', 'Ace') in the deck?", ('Spades', 'Ace') in deck)
# Out:
# First 5 cards in the deck:
# ('Clubs', 2)
# ('Clubs', 3)
# ('Clubs', 4)
# ('Clubs', 5)
# ('Clubs', 6)
#
# Total cards in deck: 52
#
# Is ('Spades', 'Ace') in the deck? True
